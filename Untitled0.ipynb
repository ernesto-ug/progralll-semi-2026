# %% [markdown]
# <a href="https://colab.research.google.com/github/ernesto-ug/progralll-semi-2026/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "hola chicos de progra 111"
print(saludo, "primera letra del saludo:", saludo[0:4])

num1 = 5.25
print(num1)

booleano = True
print(booleano)
# Out:
# hola chicos de progra 111 primera letra del saludo: hola
# 5.25
# True

# %%
print("sumar dos numero: ")
num1 =input("num1; ")
num2 =input("num2; ")
respuesta = float (num1) + float (num2 )

print("respuesta; ", respuesta)

respuesta ="suma completa"
print(respuesta, type(respuesta))
# Out:
# sumar dos numero:
# num1; 5.5
# num2; 6
# respuesta;  11.5
# suma completa <class 'str'>

# %%
print("restar dos numeros: ")
num1_sub = input("num1: ")
num2_sub = input("num2: ")
resultado_resta = float(num1_sub) - float(num2_sub)

print("resultado de la resta: ", resultado_resta)
# Out:
# restar dos numeros:
# num1: 5
# num2: 1
# resultado de la resta:  4.0

# %%
print("multiplicar dos numeros: ")
num1_mult = input("num1: ")
num2_mult = input("num2: ")
resultado_multiplicacion = float(num1_mult) * float(num2_mult)

print("resultado de la multiplicacion: ", resultado_multiplicacion)
# Out:
# multiplicar dos numeros:
# num1: 4
# num2: 4
# resultado de la multiplicacion:  16.0

# %%
print("dividir dos numeros: ")
num1_div = input("num1: ")
num2_div = input("num2: ")

# Handle division by zero to prevent errors
if float(num2_div) == 0:
    print("Error: No se puede dividir por cero.")
else:
    resultado_division = float(num1_div) / float(num2_div)
    print("resultado de la division: ", resultado_division)
# Out:
# dividir dos numeros:
# num1: 4
# num2: 2
# resultado de la division:  2.0

# %%
saludo = "hola chicos de progra lll"
print("primer elemento de la cadena ", saludo[0])
print("rango en una cadena ", saludo[0:4])
print("ultimo elemento ", saludo[-1])
print("ultimo elemento ", saludo[len(saludo)-1])
print("valores en medio sin espesificar ultimo valor  ", saludo[5:])
print("sin valor al inicio  ", saludo[:4])
print("contar del final  ", saludo[6:-1])
# Out:
# primer elemento de la cadena  h
# rango en una cadena  hola
# ultimo elemento  l
# ultimo elemento  l
